# %%
import pandas as pd

# %%
path = '../../../../output/simple_regression/modeleval/output.csv'

# %%
data = pd.read_csv(path)

# %%
data.head(n=100)
# Out:
#                                   modelName                modelType  maxBins  \
# 0             OpGBTRegressor_00000000000d_1           OpGBTRegressor       32
# 1             OpGBTRegressor_00000000000d_2           OpGBTRegressor       32
# 2             OpGBTRegressor_00000000000d_3           OpGBTRegressor       32
# 3             OpGBTRegressor_00000000000d_4           OpGBTRegressor       32
# 4             OpGBTRegressor_00000000000d_5           OpGBTRegressor       32
# 5             OpGBTRegressor_00000000000d_6           OpGBTRegressor       32
# 6             OpGBTRegressor_00000000000d_7           OpGBTRegressor       32
# 7             OpGBTRegressor_00000000000d_8           OpGBTRegressor       32
# 8             OpGBTRegressor_00000000000d_9           OpGBTRegressor       32
# 9            OpGBTRegressor_00000000000d_10           OpGBTRegressor       32
# 10           OpGBTRegressor_00000000000d_11           OpGBTRegressor       32
# 11           OpGBTRegressor_00000000000d_12           OpGBTRegressor       32
# 12           OpGBTRegressor_00000000000d_13           OpGBTRegressor       32
# 13           OpGBTRegressor_00000000000d_14           OpGBTRegressor       32
# 14           OpGBTRegressor_00000000000d_15           OpGBTRegressor       32
# 15           OpGBTRegressor_00000000000d_16           OpGBTRegressor       32
# 16           OpGBTRegressor_00000000000d_17           OpGBTRegressor       32
# 17   OpRandomForestRegressor_00000000000c_0  OpRandomForestRegressor       32
# 18   OpRandomForestRegressor_00000000000c_1  OpRandomForestRegressor       32
# 19   OpRandomForestRegressor_00000000000c_2  OpRandomForestRegressor       32
# 20   OpRandomForestRegressor_00000000000c_3  OpRandomForestRegressor       32
# 21   OpRandomForestRegressor_00000000000c_4  OpRandomForestRegressor       32
# 22   OpRandomForestRegressor_00000000000c_5  OpRandomForestRegressor       32
# 23   OpRandomForestRegressor_00000000000c_6  OpRandomForestRegressor       32
# 24   OpRandomForestRegressor_00000000000c_7  OpRandomForestRegressor       32
# 25   OpRandomForestRegressor_00000000000c_8  OpRandomForestRegressor       32
# 26   OpRandomForestRegressor_00000000000c_9  OpRandomForestRegressor       32
# 27  OpRandomForestRegressor_00000000000c_10  OpRandomForestRegressor       32
# 28  OpRandomForestRegressor_00000000000c_11  OpRandomForestRegressor       32
# 29  OpRandomForestRegressor_00000000000c_12  OpRandomForestRegressor       32
# 30  OpRandomForestRegressor_00000000000c_13  OpRandomForestRegressor       32
# 31  OpRandomForestRegressor_00000000000c_14  OpRandomForestRegressor       32
# 32  OpRandomForestRegressor_00000000000c_15  OpRandomForestRegressor       32
# 33  OpRandomForestRegressor_00000000000c_16  OpRandomForestRegressor       32
# 34  OpRandomForestRegressor_00000000000c_17  OpRandomForestRegressor       32
#
#     maxDepth  numTrees  metricValue
# 0          6       NaN     4.430991
# 1         12       NaN     4.430991
# 2          3       NaN     5.909980
# 3          6       NaN     5.909980
# 4         12       NaN     5.909980
# 5          3       NaN     4.427928
# 6          6       NaN     4.430616
# 7         12       NaN     4.430616
# 8          3       NaN     5.909980
# 9          6       NaN     5.909980
# 10        12       NaN     5.909980
# 11         3       NaN     4.429138
# 12         6       NaN     4.430577
# 13        12       NaN     4.430577
# 14         3       NaN     5.909980
# 15         6       NaN     5.909980
# 16        12       NaN     5.909980
# 17         3      50.0     4.066530
# 18         3      50.0     5.913666
# 19         3      50.0     4.066266
# 20         3      50.0     5.913666
# 21         3      50.0     4.065832
# 22         3      50.0     5.913666
# 23         6      50.0     4.077306
# 24         6      50.0     5.913666
# 25         6      50.0     4.077041
# 26         6      50.0     5.913666
# 27         6      50.0     4.076295
# 28         6      50.0     5.913666
# 29        12      50.0     4.077306
# 30        12      50.0     5.913666
# 31        12      50.0     4.077041
# 32        12      50.0     5.913666
# 33        12      50.0     4.076295
# 34        12      50.0     5.913666

# %%
data.columns.values
# Out:
# array(['modelName', 'modelType', 'maxBins', 'maxDepth', 'numTrees',
#        'metricValue'], dtype=object)

# %%
data_name_metrics = data.iloc[:,[0,5]] 
data_name_metrics_np = data_name_metrics.values

# %%
data_name_metrics_np
# Out:
# array([['OpGBTRegressor_00000000000d_1', 4.430990524870973],
#        ['OpGBTRegressor_00000000000d_2', 4.430990524870973],
#        ['OpGBTRegressor_00000000000d_3', 5.909979975084518],
#        ['OpGBTRegressor_00000000000d_4', 5.909979975084518],
#        ['OpGBTRegressor_00000000000d_5', 5.909979975084518],
#        ['OpGBTRegressor_00000000000d_6', 4.427928442073578],
#        ['OpGBTRegressor_00000000000d_7', 4.430616374837411],
#        ['OpGBTRegressor_00000000000d_8', 4.430616374837411],
#        ['OpGBTRegressor_00000000000d_9', 5.909979975084518],
#        ['OpGBTRegressor_00000000000d_10', 5.909979975084518],
#        ['OpGBTRegressor_00000000000d_11', 5.909979975084518],
#        ['OpGBTRegressor_00000000000d_12', 4.429137871227235],
#        ['OpGBTRegressor_00000000000d_13', 4.430577254149579],
#        ['OpGBTRegressor_00000000000d_14', 4.430577254149579],
#        ['OpGBTRegressor_00000000000d_15', 5.909979975084518],
#        ['OpGBTRegressor_00000000000d_16', 5.909979975084518],
#        ['OpGBTRegressor_00000000000d_17', 5.909979975084518],
#        ['OpRandomForestRegressor_00000000000c_0', 4.066529808306352],
#        ['OpRandomForestRegressor_00000000000c_1', 5.9136664375117185],
#        ['OpRandomForestRegressor_00000000000c_2', 4.066266142780773],
#        ['OpRandomForestRegressor_00000000000c_3', 5.9136664375117185],
#        ['OpRandomForestRegressor_00000000000c_4', 4.065831695480432],
#        ['OpRandomForestRegressor_00000000000c_5', 5.9136664375117185],
#        ['OpRandomForestRegressor_00000000000c_6', 4.077305700252561],
#        ['OpRandomForestRegressor_00000000000c_7', 5.9136664375117185],
#        ['OpRandomForestRegressor_00000000000c_8', 4.077041301117707],
#        ['OpRandomForestRegressor_00000000000c_9', 5.9136664375117185],
#        ['OpRandomForestRegressor_00000000000c_10', 4.076295402184487],
#        ['OpRandomForestRegressor_00000000000c_11', 5.9136664375117185],
#        ['OpRandomForestRegressor_00000000000c_12', 4.077305700252561],
#        ['OpRandomForestRegressor_00000000000c_13', 5.9136664375117185],
#        ['OpRandomForestRegressor_00000000000c_14', 4.077041301117707],
#        ['OpRandomForestRegressor_00000000000c_15', 5.9136664375117185],
#        ['OpRandomForestRegressor_00000000000c_16', 4.076295402184487],
#        ['OpRandomForestRegressor_00000000000c_17', 5.9136664375117185]],
#       dtype=object)

# %%
x = data_name_metrics_np[:,0]
y = data_name_metrics_np[:,1]
y
# Out:
# array([4.430990524870973, 4.430990524870973, 5.909979975084518,
#        5.909979975084518, 5.909979975084518, 4.427928442073578,
#        4.430616374837411, 4.430616374837411, 5.909979975084518,
#        5.909979975084518, 5.909979975084518, 4.429137871227235,
#        4.430577254149579, 4.430577254149579, 5.909979975084518,
#        5.909979975084518, 5.909979975084518, 4.066529808306352,
#        5.9136664375117185, 4.066266142780773, 5.9136664375117185,
#        4.065831695480432, 5.9136664375117185, 4.077305700252561,
#        5.9136664375117185, 4.077041301117707, 5.9136664375117185,
#        4.076295402184487, 5.9136664375117185, 4.077305700252561,
#        5.9136664375117185, 4.077041301117707, 5.9136664375117185,
#        4.076295402184487, 5.9136664375117185], dtype=object)

# %%
#%matplotlib
from matplotlib import pyplot as plt 

plt.bar(x, y, align = 'center')  
plt.title('TransmogrifAI - Simple Regression, Algorithm vs Error') 
plt.ylabel('Error') 
plt.xlabel('Algorithm Name')  
plt.xticks(rotation=90)
fig_size = plt.rcParams["figure.figsize"]
print "Current size:", fig_size
fig_size[0] = 10
fig_size[1] = 6
plt.rcParams["figure.figsize"] = fig_size
plt.show()
# Out:
# Current size: [12.0, 6.0]

# %%
data_lr = data.loc[data['modelType'] == 'OpGBTRegressor']
data_lr
# Out:
#                          modelName       modelType  maxBins  maxDepth  \
# 0    OpGBTRegressor_00000000000d_1  OpGBTRegressor       32         6
# 1    OpGBTRegressor_00000000000d_2  OpGBTRegressor       32        12
# 2    OpGBTRegressor_00000000000d_3  OpGBTRegressor       32         3
# 3    OpGBTRegressor_00000000000d_4  OpGBTRegressor       32         6
# 4    OpGBTRegressor_00000000000d_5  OpGBTRegressor       32        12
# 5    OpGBTRegressor_00000000000d_6  OpGBTRegressor       32         3
# 6    OpGBTRegressor_00000000000d_7  OpGBTRegressor       32         6
# 7    OpGBTRegressor_00000000000d_8  OpGBTRegressor       32        12
# 8    OpGBTRegressor_00000000000d_9  OpGBTRegressor       32         3
# 9   OpGBTRegressor_00000000000d_10  OpGBTRegressor       32         6
# 10  OpGBTRegressor_00000000000d_11  OpGBTRegressor       32        12
# 11  OpGBTRegressor_00000000000d_12  OpGBTRegressor       32         3
# 12  OpGBTRegressor_00000000000d_13  OpGBTRegressor       32         6
# 13  OpGBTRegressor_00000000000d_14  OpGBTRegressor       32        12
# 14  OpGBTRegressor_00000000000d_15  OpGBTRegressor       32         3
# 15  OpGBTRegressor_00000000000d_16  OpGBTRegressor       32         6
# 16  OpGBTRegressor_00000000000d_17  OpGBTRegressor       32        12
#
#     numTrees  metricValue
# 0        NaN     4.430991
# 1        NaN     4.430991
# 2        NaN     5.909980
# 3        NaN     5.909980
# 4        NaN     5.909980
# 5        NaN     4.427928
# 6        NaN     4.430616
# 7        NaN     4.430616
# 8        NaN     5.909980
# 9        NaN     5.909980
# 10       NaN     5.909980
# 11       NaN     4.429138
# 12       NaN     4.430577
# 13       NaN     4.430577
# 14       NaN     5.909980
# 15       NaN     5.909980
# 16       NaN     5.909980

# %%
data_lr_filtered = data_lr.iloc[:,[3,5]]

# %%
data_lr_np = data_lr_filtered.values
x_lr = data_lr_np[:,0]
y_lr = data_lr_np[:,1]
data_lr_np
# Out:
# array([[ 6.        ,  4.43099052],
#        [12.        ,  4.43099052],
#        [ 3.        ,  5.90997998],
#        [ 6.        ,  5.90997998],
#        [12.        ,  5.90997998],
#        [ 3.        ,  4.42792844],
#        [ 6.        ,  4.43061637],
#        [12.        ,  4.43061637],
#        [ 3.        ,  5.90997998],
#        [ 6.        ,  5.90997998],
#        [12.        ,  5.90997998],
#        [ 3.        ,  4.42913787],
#        [ 6.        ,  4.43057725],
#        [12.        ,  4.43057725],
#        [ 3.        ,  5.90997998],
#        [ 6.        ,  5.90997998],
#        [12.        ,  5.90997998]])

# %%
from matplotlib import pyplot as plt

plt.plot(x_lr,y_lr,"ob") 
plt.title('TransmogrifAI - Simple Regression, Gradient Boosted Trees') 
plt.ylabel('Error') 
plt.xlabel('MaxDepth')  
plt.xticks(rotation=90)
plt.show()

# %%
data_rf = data.loc[data['modelType'] == 'OpRandomForestRegressor']
data_rf
# Out:
#                                   modelName                modelType  maxBins  \
# 17   OpRandomForestRegressor_00000000000c_0  OpRandomForestRegressor       32
# 18   OpRandomForestRegressor_00000000000c_1  OpRandomForestRegressor       32
# 19   OpRandomForestRegressor_00000000000c_2  OpRandomForestRegressor       32
# 20   OpRandomForestRegressor_00000000000c_3  OpRandomForestRegressor       32
# 21   OpRandomForestRegressor_00000000000c_4  OpRandomForestRegressor       32
# 22   OpRandomForestRegressor_00000000000c_5  OpRandomForestRegressor       32
# 23   OpRandomForestRegressor_00000000000c_6  OpRandomForestRegressor       32
# 24   OpRandomForestRegressor_00000000000c_7  OpRandomForestRegressor       32
# 25   OpRandomForestRegressor_00000000000c_8  OpRandomForestRegressor       32
# 26   OpRandomForestRegressor_00000000000c_9  OpRandomForestRegressor       32
# 27  OpRandomForestRegressor_00000000000c_10  OpRandomForestRegressor       32
# 28  OpRandomForestRegressor_00000000000c_11  OpRandomForestRegressor       32
# 29  OpRandomForestRegressor_00000000000c_12  OpRandomForestRegressor       32
# 30  OpRandomForestRegressor_00000000000c_13  OpRandomForestRegressor       32
# 31  OpRandomForestRegressor_00000000000c_14  OpRandomForestRegressor       32
# 32  OpRandomForestRegressor_00000000000c_15  OpRandomForestRegressor       32
# 33  OpRandomForestRegressor_00000000000c_16  OpRandomForestRegressor       32
# 34  OpRandomForestRegressor_00000000000c_17  OpRandomForestRegressor       32
#
#     maxDepth  numTrees  metricValue
# 17         3      50.0     4.066530
# 18         3      50.0     5.913666
# 19         3      50.0     4.066266
# 20         3      50.0     5.913666
# 21         3      50.0     4.065832
# 22         3      50.0     5.913666
# 23         6      50.0     4.077306
# 24         6      50.0     5.913666
# 25         6      50.0     4.077041
# 26         6      50.0     5.913666
# 27         6      50.0     4.076295
# 28         6      50.0     5.913666
# 29        12      50.0     4.077306
# 30        12      50.0     5.913666
# 31        12      50.0     4.077041
# 32        12      50.0     5.913666
# 33        12      50.0     4.076295
# 34        12      50.0     5.913666

# %%
data_rf_filtered = data_rf.iloc[:,[3,5]]

# %%
data_rf_np = data_rf_filtered.values
x_rf = data_rf_np[:,0]
y_rf = data_rf_np[:,1]
data_rf_np
# Out:
# array([[ 3.        ,  4.06652981],
#        [ 3.        ,  5.91366644],
#        [ 3.        ,  4.06626614],
#        [ 3.        ,  5.91366644],
#        [ 3.        ,  4.0658317 ],
#        [ 3.        ,  5.91366644],
#        [ 6.        ,  4.0773057 ],
#        [ 6.        ,  5.91366644],
#        [ 6.        ,  4.0770413 ],
#        [ 6.        ,  5.91366644],
#        [ 6.        ,  4.0762954 ],
#        [ 6.        ,  5.91366644],
#        [12.        ,  4.0773057 ],
#        [12.        ,  5.91366644],
#        [12.        ,  4.0770413 ],
#        [12.        ,  5.91366644],
#        [12.        ,  4.0762954 ],
#        [12.        ,  5.91366644]])

# %%
from matplotlib import pyplot as plt

plt.plot(x_rf,y_rf,"ob") 
plt.title('TransmogrifAI - Simple Regression, OpRandomForestRegressor') 
plt.ylabel('Error') 
plt.xlabel('maxDepth')  
plt.xticks(rotation=90)
plt.show()
